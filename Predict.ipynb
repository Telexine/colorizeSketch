# %%
import scipy
 
from keras_contrib.layers.normalization import InstanceNormalization
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.models import Sequential, load_model

from PIL import Image
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
model = load_model('./models/gen_model.h5')
model.load_weights('./models/gen_weights.h5')
# Out:
# C:\Users\me\Anaconda3\envs\tf-gpu\lib\site-packages\keras\engine\saving.py:270: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
def imread2(path):
        return scipy.misc.imread(path, mode='RGB').astype(np.float)
c = imread2("cc.png")
c = scipy.misc.imresize(c, (128, 128))
c = np.array(c)/125.5 - 1.#edges
plt.imshow(c)
img_A = np.expand_dims(c, axis=0)
# Out:
# C:\Users\me\Anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#
# C:\Users\me\Anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   after removing the cwd from sys.path.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#model.layers[3].load_weights('./models/gen_weights.h5') ## load selected weight
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-bbe73577704c> in <module>()
# ----> 1 model.layers[3].load_weights('./models/gen_weights.h5')
#
# AttributeError: 'Conv2D' object has no attribute 'load_weights'

# %%
colorize = model.predict(img_A)

# %%
# %matplotlib inline
fig, ax = plt.subplots(1,2)

ax[0].imshow(c);
ax[0].set_title("Upload")
ax[1].set_title("Colorize")
ax[1].imshow(np.concatenate((colorize )))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
